# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, mean_squared_error, r2_score
import warnings
import os
from random import sample
from sklearn.svm import SVR

import pickle
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Functions

# %%
def predict_evaluate(pred, true, graphName = 'Energy Usage Prediction', showplots=False):
    
    diff = [abs(pred[i]-true[i]) for i in range(len(pred))]
    

    
    mape = mean_absolute_percentage_error(true, pred)
    mae = mean_absolute_error(true, pred)
    maxae = max(diff)
    mse = mean_squared_error(true, pred)
    
    if showplots:
        resultingPlot = plt.figure(figsize=(25,10))
        plt.plot(true, color='red', label='Original Usage')
        plt.plot(pred, color='blue', label='Predicted Usage')
        plt.plot(diff, color='green', label='Error')
        plt.title(graphName)
        plt.ylabel('kW')
        plt.legend()
        plt.show()
        print("Mean Absolute Percentage Error: ", mape)
        print("Mean Absolute Error: ", mae)
        print("Max Absolute Error: ", maxae)
        print("Mean Squared Error: ", mse)
    
    return {"name":graphName, "mape":mape, "mae":mae, "maxae":maxae, "mse":mse}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, MaxPooling2D, Conv2D, TimeDistributed, Flatten
from keras.callbacks import EarlyStopping

def define_model(past_window, num_features):
    
    #OPTIMIZAVEL
    model = Sequential()
    model.add(LSTM(units=128, return_sequences=True,input_shape=(past_window, num_features)))
    model.add(LSTM(units=64))
    model.add(Dense(units = 1))
    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = 'mean_absolute_error')
    #model.summary()
    
    return model

def train(model, train_generator, showplot=False):
    early_stopping = EarlyStopping(monitor="loss", 
                                   patience=2, 
                                   mode="min")
    
    history = model.fit(train_generator, 
                                  epochs=16,
                                  shuffle = False, 
                                  callbacks=[early_stopping],
                                  verbose=0
                                   )
    
    loss_per_epoch = history.history['loss']
    
    if showplot:
        plt.plot(range(len(loss_per_epoch)), loss_per_epoch)

# %%
directory = "../../datsets/LCL_Data_Transformed/train"
allHouses = sorted(os.listdir(directory))

testNumber = 5

testUsers = sample(allHouses, testNumber)

featuresNames = ['use', 'hour', 'weekday']
targetName = ['use']
past_window = 24

# %% [markdown]
# ## Test specific model SVM

# %%
for filename in testUsers:
    print("Testing with ", filename)
    
    f = os.path.join(directory, filename)
    if os.path.isfile(f):
        df = pd.read_csv(f, delimiter = ',')

    specific_model = SVR(kernel = "rbf")
        
    features = df[featuresNames].values
    target = df[targetName].values.reshape(-1, 1)
    
    x_train, x_test, y_train, y_test = train_test_split(features,target, test_size=24*30, shuffle=False)


    #SCALE
    x_scaler = StandardScaler()
    x_train = x_scaler.fit_transform(x_train)
    x_test = x_scaler.transform(x_test)
    

    y_scaler = StandardScaler()
    y_train = y_scaler.fit_transform(y_train)

    #Time series
    batch_size=1
    train_generator = TimeseriesGenerator(x_train, y_train, length=past_window, batch_size=batch_size)
    test_generator = TimeseriesGenerator(x_test, y_test, length=past_window, batch_size=batch_size)
    svr_x_Train = [arr[0].flatten() for arr in train_generator]
    svr_y_Train = [arr[1].flatten() for arr in train_generator]
    svr_x_Test = [arr[0].flatten() for arr in test_generator]
    
    specific_model.fit(svr_x_Train, svr_y_Train)


    prediction = specific_model.predict(svr_x_Test).reshape(-1, 1)
    prediction = y_scaler.inverse_transform(prediction)
            
    predict_evaluate(prediction, y_test[past_window:], showplots=True)
# Out:
# Testing with  MAC003232.csv
# Mean Absolute Percentage Error:  0.39770311164203703
# Mean Absolute Error:  0.13265306382278563
# Max Absolute Error:  [1.11440787]
# Mean Squared Error:  0.05307380983472827
# Testing with  MAC002565.csv
# Mean Absolute Percentage Error:  0.48760410867263926
# Mean Absolute Error:  0.06506315770866969
# Max Absolute Error:  [0.93294365]
# Mean Squared Error:  0.02014871491047868
# Testing with  MAC000509.csv
# Mean Absolute Percentage Error:  0.39299027861113583
# Mean Absolute Error:  0.10853273565945934
# Max Absolute Error:  [0.93006942]
# Mean Squared Error:  0.033284502739214364
# Testing with  MAC000205.csv
# Mean Absolute Percentage Error:  0.3584311592363003
# Mean Absolute Error:  0.094957750515526
# Max Absolute Error:  [1.59095878]
# Mean Squared Error:  0.03402206407104238
# Testing with  MAC002747.csv
# Mean Absolute Percentage Error:  0.5616610690524944
# Mean Absolute Error:  0.10927091009704726
# Max Absolute Error:  [1.20026415]
# Mean Squared Error:  0.03407427791859408

# %% [markdown]
# ## Test specific model LSTM

# %%
for filename in testUsers:
    print("Testing with ", filename)
    
    f = os.path.join(directory, filename)
    if os.path.isfile(f):
        df = pd.read_csv(f, delimiter = ',')

    specific_model = define_model(past_window, len(featuresNames))
        
    features = df[featuresNames].values
    target = df[targetName].values.reshape(-1, 1)
    
    x_train, x_test, y_train, y_test = train_test_split(features,target, test_size=24*30, shuffle=False)


    #SCALE
    x_scaler = StandardScaler()
    x_train = x_scaler.fit_transform(x_train)
    x_test = x_scaler.transform(x_test)
    

    y_scaler = StandardScaler()
    y_train = y_scaler.fit_transform(y_train)

    #Time series
    batch_size=64
    train_generator = TimeseriesGenerator(x_train, y_train, length=past_window, batch_size=batch_size)
    test_generator = TimeseriesGenerator(x_test, y_test, length=past_window, batch_size=batch_size)
    
    train(specific_model, train_generator)


    prediction = specific_model.predict(test_generator).reshape(-1, 1)
    prediction = y_scaler.inverse_transform(prediction)
    predict_evaluate(prediction, y_test[past_window:], showplots=True)
# Out:
# Testing with  MAC003232.csv
# Mean Absolute Percentage Error:  0.5796229834154927
# Mean Absolute Error:  0.14917405289144167
# Max Absolute Error:  [0.99995099]
# Mean Squared Error:  0.04936146011247456
# Testing with  MAC002565.csv
# Mean Absolute Percentage Error:  0.7763625040249376
# Mean Absolute Error:  0.0732995768825941
# Max Absolute Error:  [0.91812704]
# Mean Squared Error:  0.019154849221347556
# Testing with  MAC000509.csv
# Mean Absolute Percentage Error:  0.45574498840538086
# Mean Absolute Error:  0.10591875559805218
# Max Absolute Error:  [0.8724865]
# Mean Squared Error:  0.02763791337599173
# Testing with  MAC000205.csv
# Mean Absolute Percentage Error:  0.4927203645095831
# Mean Absolute Error:  0.11239658390591456
# Max Absolute Error:  [1.5025394]
# Mean Squared Error:  0.033042194792196646
# Testing with  MAC002747.csv
# Mean Absolute Percentage Error:  0.6246349430012558
# Mean Absolute Error:  0.11140679097280504
# Max Absolute Error:  [1.02205113]
# Mean Squared Error:  0.03098770931871386

# %%
testUsers = ["MAC003239.csv"]
featuresNames = ['use']
targetName = ['use']
past_window = 24

for filename in testUsers:
    print("Testing with ", filename)
    
    f = os.path.join(directory, filename)
    if os.path.isfile(f):
        df = pd.read_csv(f, delimiter = ',')

    specific_model = define_model(past_window, len(featuresNames))
        
    features = df[featuresNames].values
    target = df[targetName].values.reshape(-1, 1)
    
    x_train, x_test, y_train, y_test = train_test_split(features,target, test_size=24*30, shuffle=False)


    #SCALE
    x_scaler = StandardScaler()
    x_train = x_scaler.fit_transform(x_train)
    x_test = x_scaler.transform(x_test)
    

    y_scaler = StandardScaler()
    y_train = y_scaler.fit_transform(y_train)

    #Time series
    batch_size=64
    train_generator = TimeseriesGenerator(x_train, y_train, length=past_window, batch_size=batch_size)
    test_generator = TimeseriesGenerator(x_test, y_test, length=past_window, batch_size=batch_size)
    
    train(specific_model, train_generator)


    prediction = specific_model.predict(test_generator).reshape(-1, 1)
    prediction = y_scaler.inverse_transform(prediction)
    predict_evaluate(prediction, y_test[past_window:], showplots=True)
# Out:
# Testing with  MAC003239.csv
# Mean Absolute Percentage Error:  0.32350375201575404
# Mean Absolute Error:  0.04911532960152483
# Max Absolute Error:  0.5338323611021042
# Mean Squared Error:  0.006502095754422972

# %% [markdown]
# ## loop, takes too much time with smv

# %%
x_trainALL = []
y_trainALL = []
for filename in trainUsers:
    print("Training with ", filename)
    
    f = os.path.join(directory, filename)
    if os.path.isfile(f):
        df = pd.read_csv(f, delimiter = ',')
        #print(df.isna().values.any())
        #print(df[df['use'].isna()])
        #continue
        
        features = df[featuresNames].values
        target = df[targetName].values.reshape(-1,1)
        
        #SCALE
        x_scaler = StandardScaler()
        x_train = x_scaler.fit_transform(features)

        y_scaler = StandardScaler()
        y_train = y_scaler.fit_transform(target)
        
        #Time series
        batch_size=1
        train_generator = TimeseriesGenerator(x_train, y_train, length=past_window, batch_size=batch_size)
        svr_x_Train = [arr[0].flatten() for arr in train_generator]
        svr_y_Train = [arr[1].flatten() for arr in train_generator]
        
        x_trainALL += svr_x_Train
        y_trainALL += svr_y_Train
        

model.fit(x_trainALL, y_trainALL)
                
#prediction = model.predict(x_test).reshape(-1, 1)
#prediction = y_scaler.inverse_transform(prediction)
# Out:
# Training with  MAC000289.csv
# Training with  MAC002565.csv
# Training with  MAC002540.csv
# Training with  MAC000720.csv
# Training with  MAC002335.csv
# Training with  MAC002285.csv
# Training with  MAC000116.csv
# Training with  MAC003289.csv
# Training with  MAC000800.csv
# Training with  MAC001445.csv

# %%
a = [1]
b = [0]

predict_evaluate(a, b, showplots=True)
# Out:
# Mean Absolute Percentage Error:  4503599627370496.0
# Mean Absolute Error:  1.0
# Max Absolute Error:  1
# Mean Squared Error:  1.0
# {'name': 'Energy Usage Prediction',
#  'mape': 4503599627370496.0,
#  'mae': 1.0,
#  'maxae': 1,
#  'mse': 1.0}
