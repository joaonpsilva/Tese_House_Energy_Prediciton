# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %%
df = pd.read_csv("../datsets/dataset1/archive/HomeC.csv", delimiter = ',')

#Droped cloudcover (mixed type)
#df= df.drop("cloudCover", axis=1) 

#Dropped last line (null)

df
#df.to_csv('../datsets/dataset1/archive/HomeC.csv', index=False)
# Out:
#               time  use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 0       1451624400  0.932833  0.003483            0.932833         0.000033
# 1       1451624401  0.934333  0.003467            0.934333         0.000000
# 2       1451624402  0.931817  0.003467            0.931817         0.000017
# 3       1451624403  1.022050  0.003483            1.022050         0.000017
# 4       1451624404  1.139400  0.003467            1.139400         0.000133
# ...            ...       ...       ...                 ...              ...
# 503905  1452128305  1.601233  0.003183            1.601233         0.000050
# 503906  1452128306  1.599333  0.003233            1.599333         0.000050
# 503907  1452128307  1.924267  0.003217            1.924267         0.000033
# 503908  1452128308  1.978200  0.003217            1.978200         0.000050
# 503909  1452128309  1.990950  0.003233            1.990950         0.000050
#
# ...

# %%
df.isnull().sum() #check for null values
# Out:
# Unnamed: 0             0
# time                   0
# use [kW]               0
# gen [kW]               0
# House overall [kW]     0
# Dishwasher [kW]        0
# Furnace 1 [kW]         0
# Furnace 2 [kW]         0
# Home office [kW]       0
# Fridge [kW]            0
# Wine cellar [kW]       0
# Garage door [kW]       0
# Kitchen 12 [kW]        0
# Kitchen 14 [kW]        0
# Kitchen 38 [kW]        0
# Barn [kW]              0
# Well [kW]              0
# Microwave [kW]         0
# Living room [kW]       0
# Solar [kW]             0
# temperature            0
# icon                   0
# humidity               0
# visibility             0
# summary                0
# apparentTemperature    0
# pressure               0
# windSpeed              0
# cloudCover             0
# windBearing            0
# precipIntensity        0
# dewPoint               0
# precipProbability      0
# dtype: int64

# %%
plt.plot(df["time"][:10000], df["use [kW]"][:10000])

# %%
y = df["use [kW]"]

xnames = list(df.columns)
xnames.remove('time')                 
xnames.remove('use [kW]')             #this is y
xnames.remove('House overall [kW]')   #equal to use
xnames.remove('gen [kW]')             #generation
xnames.remove('Solar [kW]')           #solar generation
xnames.remove('summary')
xnames.remove('icon')
xnames.remove('apparentTemperature')
xnames.remove('visibility')
xnames.remove('pressure')
xnames.remove('windSpeed')
xnames.remove('windBearing')
xnames.remove('dewPoint')
xnames.remove('precipProbability')

x = df[xnames]
x
# Out:
#         Dishwasher [kW]  Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  \
# 0              0.000033        0.020700        0.061917          0.442633
# 1              0.000000        0.020717        0.063817          0.444067
# 2              0.000017        0.020700        0.062317          0.446067
# 3              0.000017        0.106900        0.068517          0.446583
# 4              0.000133        0.236933        0.063983          0.446533
# ...                 ...             ...             ...               ...
# 503905         0.000050        0.085267        0.642417          0.041783
# 503906         0.000050        0.104017        0.625033          0.041750
# 503907         0.000033        0.422383        0.637733          0.042033
# 503908         0.000050        0.495667        0.620367          0.042100
# 503909         0.000050        0.494700        0.634133          0.042100
#
#         Fridge [kW]  Wine cellar [kW]  Garage door [kW]  Kitchen 12 [kW]  \
# ...

# %%
x = x.values
y = y.values.reshape(-1, 1)

print(x.shape)
print(y.shape)
# Out:
# (503910, 17)
# (503910, 1)

# %%
st_x = StandardScaler()
st_y = StandardScaler()
X = st_x.fit_transform(x)
Y = st_y.fit_transform(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
print(x.shape)
print(x_train.shape)
print(x_test.shape)
# Out:
# (503910, 17)
# (377932, 17)
# (125978, 17)

# %%
regressor = SVR(kernel = 'rbf')

# %%
regressor.fit(x_train, y_train)
# Out:
# /home/joaonps/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
